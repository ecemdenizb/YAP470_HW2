# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler

# %%
#sigmoid fonk f(x)=1/(1+exp^-x)
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def deriv_sigmoid(x):
    return(x*(1-x))

# %%
def relu(x):
    return np.maximum(0,x)

# %%
def deriv_relu(x):
    der=list()
    der.clear()
    for val in x:
        if val>0:
            der.append(1)
        else:
            der.append(0)
    return der

# %%
def get_loss(y_act, y_pred):
    error=0
    for i in range(len(y_act)):
        error+=abs(np.subtract(y_act[i],y_pred[i]))    
    return error

# %%
def initialize(x, neuron_num):
    np.random.seed(12345)
    w1=2*np.random.random((len(x.columns), neuron_num))-1
    w2=2*np.random.random((neuron_num, 1))-1
    bias1=2*np.random.random()-1
    bias2=2*np.random.random()-1
    return w1, w2, bias1, bias2

# %%
def forward_prop(w1, w2, bias1, bias2, x):
    x=x.reshape(13,1)
    z1=np.dot(w1.T,x)+bias1
    out1=relu(z1)
    z2=np.dot(w2.T,out1)+bias2
    out2=relu(z2) 
    return z1, out1, z2, out2

# %%
def back_prop(w1, w2, bias1, bias2, x, y, z1, out1, z2, out2, lr, j):
    x=x.reshape(13,1)
   # err_2=np.add(mse2,abs(np.subtract(y,out2.sum(axis=0))))
    err_2=2*(np.subtract(out2.sum(axis=0), y)) # karenin turevi oldugu icin 2*(y_pred-y_act)
   # adj_w2=lr*(np.dot(mse2_,out1.T))
    dummy_2=np.array(deriv_relu(z2)).reshape(1,1)
    dc_dw2=lr*np.dot(out1,dummy_2)*err_2
    #w2=np.add(w2, adj_w2.T)
    w2=np.subtract(w2,dc_dw2)
    dc_db2=lr*err_2
    bias2-=dc_db2

#    err_1=np.add(mse1,abs(np.subtract(y,out1.sum(axis=0))))
#    mse1_=np.divide(err_1,j)
#    adj_w1=lr*(np.dot(mse1_,x.T)).reshape(13,1)
#    w1_dummy=w1.T
#    w1_dummy=np.add(w1_dummy,adj_w1.T)
#    w1=w1_dummy.T
    #bias-=lr*err
    err_1= 2*(np.subtract(y, out1.sum(axis=0)))
    dummy_1=np.array(deriv_relu(z1)).reshape(7,1)
    dc_dw1=lr*np.dot(x,dummy_1.T)*err_1
    w1=np.subtract(w1,dc_dw1)
    dc_db1=lr*err_1
    bias1-=dc_db1
    return w1, w2, bias1, bias2

# %%
pd.set_option("display.max_rows", None,
             "display.max_columns", None)

# %%
columns=("CRIM","ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV")

# %%
ds=pd.read_csv("/Users/ecemdenizbabaoglan/Desktop/TOBBETU/yap470/housing.csv", sep='\s+', engine='python', names=columns)

# %%
#ds.head()

# %%
#ds.isnull().sum()

# %%
#ds.describe(include='all')

# %%
target=ds.loc[:,'MEDV'].copy()

# %%
data=ds.drop('MEDV', axis=1).copy()

# %%
w1, w2, bias1, bias2=initialize(data,7)

# %%
scaler=StandardScaler()
data_normalized=scaler.fit_transform(data)
target=target.to_numpy()

# %%
cutoff = int(len(data) * 0.8)
x_train, x_test = data_normalized[:cutoff], data_normalized[cutoff:]
y_train, y_test = target[:cutoff], target[cutoff:]

# %%
epochs=50

# %%
lr=0.01

# %%
output1=list()
output2=list()
z_1=list()
z_2=list()
loss=0
loss_test=0

# %%
for e in range(epochs):
    output1.clear()
    output2.clear()
    z_1.clear()
    z_2.clear()
    errors=0
    for i in range(len(y_train)):   
        z1, out1, z2, out2= forward_prop(w1, w2, bias1, bias2, x_train[i])
        output1.append(out1)
        output2.append(out2)
       # predicted[i]=output[i].sum(axis=0)
        w1, w2, bias1, bias2 = back_prop(w1, w2, bias1, bias2, x_train[i], y_train[i], z1, output1[i], z2, output2[i], lr, i+1)

# %%
for i in range(len(y_train)):
   # print(y_train[i], output[i].sum(axis=0))
    loss+=(y_train[i]-(output2[i].sum(axis=0)))

# %%
print(loss/(len(y_train)))
# Out:
# [-4.52883056e-16]

# %%
print(output2[1])
# Out:
# [[19.37281744]]

# %%
out_test=list()
for i in range(len(y_test)): 
    z_test1, out_test1, z_test2, out_test2=forward_prop(w1, w2, bias1, bias2, x_test[i])
    out_test.append(out_test2)
    loss_test+=(y_test[i]-(out_test[i].sum(axis=0)))
print(loss_test/(len(y_test)))
# Out:
# [-3.25289495]

# %%
for i in range(len(y_train)):
    print(y_train[i], output2[i])
# Out:
# 24.0 [[19.27838515]]
# 21.6 [[19.37281744]]
# 34.7 [[19.41736109]]
# 33.4 [[19.72301387]]
# 36.2 [[19.99655359]]
# 28.7 [[20.32062252]]
# 22.9 [[20.48821007]]
# 27.1 [[20.53644587]]
# 16.5 [[20.66771695]]
# 18.9 [[20.58436261]]
# 15.0 [[20.55067536]]
# 18.9 [[20.43966185]]
# 21.7 [[20.40886862]]
# 20.4 [[20.43469124]]
# 18.2 [[20.43399742]]
# 19.9 [[20.38931747]]
# 23.1 [[20.37953112]]
# 17.5 [[20.4339405]]
# 20.2 [[20.37526169]]
# 18.2 [[20.37175646]]
# 13.6 [[20.32832133]]
# 19.6 [[20.1937549]]
# 15.2 [[20.1818798]]
# 14.5 [[20.08224221]]
# 15.6 [[19.97059736]]
# 13.9 [[19.88318541]]
# 16.6 [[19.76352171]]
# 14.8 [[19.70025127]]
# 18.4 [[19.60224625]]
# 21.0 [[19.57820132]]
# 12.7 [[19.6066373]]
# 14.5 [[19.46850455]]
# 13.2 [[19.36913446]]
# 13.1 [[19.24575177]]
# 13.5 [[19.12283673]]
# 18.9 [[19.01038]]
# 20.0 [[19.0081724]]
# 21.0 [[19.02800895]]
# 24.7 [[19.06744877]]
# 30.8 [[19.1800998]]
# 34.9 [[19.4124978]]
# 26.6 [[19.72224785]]
# 25.3 [[19.85980289]]
# 24.7 [[19.96860683]]
# 21.2 [[20.06323469]]
# 19.3 [[20.08597]]
# 20.0 [[20.0702506]]
# 16.6 [[20.06884559]]
# 14.4 [[19.99946868]]
# 19.4 [[19.8874793]]
# 19.7 [[19.87772972]]
# 20.5 [[19.87417512]]
# 25.0 [[19.88669162]]
# 23.4 [[19.98895779]]
# 18.9 [[20.05717863]]
# 35.4 [[20.03403506]]
# 24.7 [[20.34135436]]
# 31.6 [[20.42852727]]
# 23.3 [[20.65195673]]
# 19.6 [[20.70491759]]
# 18.7 [[20.68281924]]
# 16.0 [[20.64316285]]
# 22.2 [[20.5502996]]
# 25.0 [[20.58329361]]
# 33.0 [[20.67162773]]
# 23.5 [[20.91819518]]
# 19.4 [[20.96983127]]
# 22.0 [[20.93843465]]
# 17.4 [[20.95966596]]
# 20.9 [[20.88847264]]
# 24.2 [[20.88870318]]
# 21.7 [[20.95492912]]
# 22.8 [[20.96983054]]
# 23.4 [[21.00643393]]
# 24.1 [[21.05430525]]
# 21.4 [[21.11521914]]
# 20.0 [[21.12091476]]
# 20.8 [[21.09849647]]
# 21.2 [[21.09252654]]
# 20.3 [[21.09467601]]
# 28.0 [[21.07878249]]
# 23.9 [[21.21720684]]
# 24.8 [[21.2708627]]
# 22.9 [[21.34144545]]
# 23.9 [[21.37261654]]
# 26.6 [[21.42316421]]
# 22.5 [[21.52670092]]
# 22.2 [[21.5461669]]
# 23.6 [[21.55924357]]
# 28.7 [[21.60005869]]
# 22.6 [[21.74205752]]
# 22.0 [[21.75921637]]
# 22.9 [[21.76403204]]
# 25.0 [[21.7867514]]
# 20.6 [[21.85101637]]
# 28.4 [[21.82599605]]
# 21.4 [[21.95747612]]
# 38.7 [[21.9463266]]
# 43.8 [[22.28140007]]
# 33.2 [[22.71177207]]
# 27.5 [[22.92153663]]
# 26.5 [[23.0131059]]
# 18.6 [[23.08284378]]
# 19.3 [[22.9931869]]
# 20.1 [[22.91932316]]
# 19.5 [[22.8629367]]
# 19.5 [[22.79567797]]
# 20.4 [[22.72976441]]
# 19.8 [[22.68316912]]
# 19.4 [[22.62550574]]
# 21.7 [[22.56099562]]
# 22.8 [[22.54377571]]
# 18.8 [[22.5489002]]
# 18.7 [[22.47392219]]
# 18.5 [[22.39844375]]
# 18.3 [[22.32047487]]
# 21.2 [[22.24006537]]
# 19.2 [[22.21926407]]
# 20.4 [[22.15887879]]
# 19.3 [[22.12370121]]
# 22.0 [[22.06722719]]
# 20.3 [[22.06588264]]
# 20.5 [[22.03056499]]
# 17.3 [[21.99995369]]
# 18.8 [[21.90595462]]
# 21.4 [[21.84383552]]
# 15.7 [[21.83495881]]
# 16.2 [[21.71225964]]
# 18.0 [[21.60201444]]
# 14.3 [[21.52997416]]
# 19.2 [[21.38537467]]
# 19.6 [[21.34166718]]
# 23.0 [[21.30683384]]
# 18.4 [[21.34069716]]
# 15.6 [[21.28188322]]
# 18.1 [[21.16824555]]
# 17.4 [[21.10688064]]
# 17.1 [[21.03274303]]
# 13.3 [[20.95408817]]
# 17.8 [[20.8010064]]
# 14.0 [[20.74098628]]
# 14.4 [[20.60616655]]
# 13.4 [[20.48204322]]
# 15.6 [[20.34040235]]
# 11.8 [[20.24559431]]
# 13.8 [[20.07668242]]
# 15.6 [[19.95114877]]
# 14.6 [[19.8641258]]
# 17.8 [[19.75884328]]
# 15.4 [[19.71966642]]
# 21.5 [[19.63327309]]
# 19.6 [[19.67060763]]
# 15.3 [[19.66919547]]
# 19.4 [[19.58181156]]
# 17.0 [[19.57817533]]
# 15.6 [[19.52661183]]
# 13.1 [[19.44807959]]
# 41.3 [[19.321118]]
# 24.3 [[19.76069564]]
# 23.3 [[19.85148172]]
# 27.0 [[19.92045209]]
# 50.0 [[20.06204305]]
# 50.0 [[20.66080219]]
# 50.0 [[21.24758614]]
# 22.7 [[21.82263442]]
# 25.0 [[21.84018173]]
# 50.0 [[21.9033781]]
# 23.8 [[22.46531054]]
# 23.8 [[22.49200433]]
# 22.3 [[22.51816424]]
# 17.4 [[22.51380095]]
# 19.1 [[22.41152493]]
# 23.1 [[22.34529444]]
# 23.6 [[22.36038855]]
# 22.6 [[22.38518078]]
# 29.4 [[22.38947716]]
# 23.2 [[22.52968762]]
# 24.6 [[22.54309387]]
# 29.9 [[22.58423199]]
# 37.2 [[22.73054735]]
# 39.8 [[23.0199364]]
# 36.2 [[23.35553767]]
# 37.9 [[23.61242692]]
# 32.5 [[23.89817838]]
# 26.4 [[24.07021481]]
# 29.6 [[24.11681052]]
# 50.0 [[24.22647431]]
# 32.0 [[24.74194482]]
# 29.8 [[24.88710592]]
# 34.9 [[24.98536381]]
# 37.0 [[25.18365653]]
# 30.5 [[25.4199834]]
# 36.4 [[25.52158373]]
# 31.1 [[25.73915206]]
# 29.1 [[25.84636902]]
# 50.0 [[25.91144164]]
# 33.3 [[26.3932128]]
# 30.3 [[26.53134855]]
# 34.6 [[26.60672158]]
# 34.9 [[26.76658714]]
# 32.9 [[26.9292554]]
# 24.1 [[27.04867029]]
# 42.3 [[26.98969689]]
# 48.5 [[27.29590295]]
# 50.0 [[27.71998489]]
# 22.6 [[28.16558519]]
# 24.4 [[28.05427349]]
# 22.5 [[27.98118802]]
# 24.4 [[27.87156426]]
# 20.0 [[27.80213297]]
# 21.7 [[27.64609031]]
# 19.3 [[27.52716851]]
# 22.4 [[27.36262514]]
# 28.1 [[27.26337263]]
# 23.7 [[27.28010518]]
# 25.0 [[27.20850308]]
# 23.3 [[27.16433302]]
# 28.7 [[27.08704636]]
# 21.5 [[27.11930543]]
# 23.0 [[27.00691932]]
# 26.7 [[26.92678093]]
# 21.7 [[26.92224532]]
# 27.5 [[26.81780041]]
# 30.1 [[26.8314444]]
# 44.8 [[26.89681551]]
# 50.0 [[27.2548792]]
# 37.6 [[27.70978162]]
# 31.6 [[27.90758599]]
# 46.7 [[27.98143427]]
# 31.5 [[28.35580558]]
# 24.3 [[28.41868947]]
# 31.7 [[28.33631568]]
# 41.7 [[28.40358937]]
# 48.3 [[28.66951758]]
# 29.0 [[29.06212723]]
# 24.0 [[29.06088468]]
# 25.1 [[28.95966699]]
# 31.5 [[28.88247365]]
# 23.7 [[28.93482418]]
# 23.3 [[28.83012769]]
# 22.0 [[28.71952514]]
# 20.1 [[28.58513464]]
# 22.2 [[28.41543194]]
# 23.7 [[28.29112331]]
# 17.6 [[28.19930084]]
# 18.5 [[27.98731482]]
# 24.3 [[27.79756853]]
# 20.5 [[27.72761716]]
# 24.5 [[27.58306481]]
# 26.2 [[27.52140352]]
# 24.4 [[27.49497545]]
# 24.8 [[27.43307594]]
# 29.6 [[27.38041442]]
# 42.8 [[27.42480613]]
# 21.9 [[27.73231001]]
# 20.9 [[27.61566381]]
# 44.0 [[27.48135053]]
# 50.0 [[27.81172352]]
# 36.0 [[28.25548905]]
# 30.1 [[28.41037927]]
# 33.8 [[28.44417168]]
# 43.1 [[28.55128825]]
# 48.8 [[28.84226248]]
# 31.0 [[29.24141723]]
# 36.5 [[29.27658889]]
# 22.8 [[29.42105711]]
# 30.7 [[29.28863597]]
# 50.0 [[29.31686325]]
# 43.5 [[29.73052599]]
# 20.7 [[30.00591547]]
# 21.1 [[29.81979716]]
# 25.2 [[29.64540121]]
# 24.4 [[29.55649319]]
# 35.2 [[29.45336333]]
# 32.4 [[29.56829606]]
# 32.0 [[29.62493014]]
# 33.2 [[29.67243154]]
# 33.1 [[29.7429829]]
# 29.1 [[29.81012325]]
# 35.1 [[29.79592078]]
# 45.4 [[29.90200237]]
# 35.4 [[30.21196232]]
# 46.0 [[30.31572307]]
# 50.0 [[30.62940861]]
# 32.2 [[31.01682044]]
# 22.0 [[31.04048403]]
# 20.1 [[30.85967435]]
# 23.2 [[30.64448086]]
# 22.3 [[30.49559124]]
# 24.8 [[30.33167942]]
# 28.5 [[30.22104583]]
# 37.3 [[30.18662491]]
# 27.9 [[30.32889242]]
# 23.9 [[30.28031457]]
# 21.7 [[30.15270828]]
# 28.6 [[29.98365411]]
# 27.1 [[29.95598103]]
# 20.3 [[29.89886141]]
# 22.5 [[29.70688418]]
# 29.0 [[29.5627465]]
# 24.8 [[29.55149157]]
# 22.0 [[29.45646174]]
# 26.4 [[29.3073325]]
# 33.1 [[29.24918585]]
# 36.1 [[29.32620213]]
# 28.4 [[29.46167809]]
# 33.4 [[29.44044453]]
# 28.2 [[29.51963564]]
# 22.8 [[29.49324293]]
# 20.3 [[29.35937807]]
# 16.1 [[29.17819051]]
# 22.1 [[28.9166267]]
# 19.4 [[28.78029416]]
# 21.6 [[28.59268828]]
# 23.8 [[28.45283451]]
# 16.2 [[28.35977782]]
# 17.8 [[28.11658227]]
# 19.8 [[27.91025062]]
# 23.1 [[27.74804561]]
# 21.0 [[27.6550847]]
# 23.8 [[27.521983]]
# 23.1 [[27.44754334]]
# 20.4 [[27.36059248]]
# 18.5 [[27.22138063]]
# 25.0 [[27.04695301]]
# 24.6 [[27.00601395]]
# 23.0 [[26.95789367]]
# 22.2 [[26.8787358]]
# 19.3 [[26.78516108]]
# 22.6 [[26.63545786]]
# 19.8 [[26.55474871]]
# 17.1 [[26.41965373]]
# 19.4 [[26.23326066]]
# 22.2 [[26.09659544]]
# 20.7 [[26.01866354]]
# 21.1 [[25.91229026]]
# 19.5 [[25.81604446]]
# 18.5 [[25.68972357]]
# 20.6 [[25.5459291]]
# 19.0 [[25.44701052]]
# 18.7 [[25.31807031]]
# 32.7 [[25.1857089]]
# 16.5 [[25.33599472]]
# 23.9 [[25.15927483]]
# 31.2 [[25.13408933]]
# 17.5 [[25.25540754]]
# 17.2 [[25.10029939]]
# 23.1 [[24.94229341]]
# 24.5 [[24.90544754]]
# 26.6 [[24.89733859]]
# 22.9 [[24.93139182]]
# 24.1 [[24.89076398]]
# 18.6 [[24.8749487]]
# 30.1 [[24.74944973]]
# 18.2 [[24.85646073]]
# 20.6 [[24.72333152]]
# 17.8 [[24.64086489]]
# 21.7 [[24.50404759]]
# 22.7 [[24.44796664]]
# 22.6 [[24.4130073]]
# 25.0 [[24.37674716]]
# 19.9 [[24.38921221]]
# 20.8 [[24.29942797]]
# 16.8 [[24.22943941]]
# 21.9 [[24.08085062]]
# 27.5 [[24.03723361]]
# 21.9 [[24.10648894]]
# 23.1 [[24.06235916]]
# 50.0 [[24.04311198]]
# 50.0 [[24.56224974]]
# 50.0 [[25.07100474]]
# 50.0 [[25.56958465]]
# 50.0 [[26.05819295]]
# 13.8 [[26.53702909]]
# 13.8 [[26.28228851]]
# 15.0 [[26.03264274]]
# 13.9 [[25.81198989]]
# 13.3 [[25.57375009]]
# 13.1 [[25.32827509]]
# 10.2 [[25.08370959]]
# 10.4 [[24.78603539]]
# 10.9 [[24.49831469]]
# 11.3 [[24.22634839]]
# 12.3 [[23.96782143]]
# 8.8 [[23.734465]]
# 7.2 [[23.4357757]]
# 10.5 [[23.11106018]]
# 7.4 [[22.85883898]]
# 10.2 [[22.5496622]]
# 11.5 [[22.30266896]]
# 15.1 [[22.08661558]]
# 23.2 [[21.94688326]]
# 9.7 [[21.9719456]]
# 13.8 [[21.72650669]]
# 12.7 [[21.56797655]]
# 13.1 [[21.39061702]]
# 12.5 [[21.22480468]]
# 8.5 [[21.05030859]]
# 5.0 [[20.79930242]]
# 6.3 [[20.48331637]]
# 5.6 [[20.19965004]]
# 7.2 [[19.90765704]]
# 12.1 [[19.6535039]]
# 8.3 [[19.50243382]]

# %%
print(output2)
# Out:
# [array([[19.27838515]]), array([[19.37281744]]), array([[19.41736109]]), array([[19.72301387]]), array([[19.99655359]]), array([[20.32062252]]), array([[20.48821007]]), array([[20.53644587]]), array([[20.66771695]]), array([[20.58436261]]), array([[20.55067536]]), array([[20.43966185]]), array([[20.40886862]]), array([[20.43469124]]), array([[20.43399742]]), array([[20.38931747]]), array([[20.37953112]]), array([[20.4339405]]), array([[20.37526169]]), array([[20.37175646]]), array([[20.32832133]]), array([[20.1937549]]), array([[20.1818798]]), array([[20.08224221]]), array([[19.97059736]]), array([[19.88318541]]), array([[19.76352171]]), array([[19.70025127]]), array([[19.60224625]]), array([[19.57820132]]), array([[19.6066373]]), array([[19.46850455]]), array([[19.36913446]]), array([[19.24575177]]), array([[19.12283673]]), array([[19.01038]]), array([[19.0081724]]), array([[19.02800895]]), array([[19.06744877]]), array([[19.1800998]]), array([[19.4124978]]), array([[19.72224785]]), array([[19.85980289]]), array([[19.96860683]]), array([[20.06323469]]), array([[20.08597]]), array([[20.0702506]]), array([[20.06884559]]), array([[19.99946868]]), array([[19.8874793]]), array([[19.87772972]]), array([[19.87417512]]), array([[19.88669162]]), array([[19.98895779]]), array([[20.05717863]]), array([[20.03403506]]), array([[20.34135436]]), array([[20.42852727]]), array([[20.65195673]]), array([[20.70491759]]), array([[20.68281924]]), array([[20.64316285]]), array([[20.5502996]]), array([[20.58329361]]), array([[20.67162773]]), array([[20.91819518]]), array([[20.96983127]]), array([[20.93843465]]), array([[20.95966596]]), array([[20.88847264]]), array([[20.88870318]]), array([[20.95492912]]), array([[20.96983054]]), array([[21.00643393]]), array([[21.05430525]]), array([[21.11521914]]), array([[21.12091476]]), array([[21.09849647]]), array([[21.09252654]]), array([[21.09467601]]), array([[21.07878249]]), array([[21.21720684]]), array([[21.2708627]]), array([[21.34144545]]), array([[21.37261654]]), array([[21.42316421]]), array([[21.52670092]]), array([[21.5461669]]), array([[21.55924357]]), array([[21.60005869]]), array([[21.74205752]]), array([[21.75921637]]), array([[21.76403204]]), array([[21.7867514]]), array([[21.85101637]]), array([[21.82599605]]), array([[21.95747612]]), array([[21.9463266]]), array([[22.28140007]]), array([[22.71177207]]), array([[22.92153663]]), array([[23.0131059]]), array([[23.08284378]]), array([[22.9931869]]), array([[22.91932316]]), array([[22.8629367]]), array([[22.79567797]]), array([[22.72976441]]), array([[22.68316912]]), array([[22.62550574]]), array([[22.56099562]]), array([[22.54377571]]), array([[22.5489002]]), array([[22.47392219]]), array([[22.39844375]]), array([[22.32047487]]), array([[22.24006537]]), array([[22.21926407]]), array([[22.15887879]]), array([[22.12370121]]), array([[22.06722719]]), array([[22.06588264]]), array([[22.03056499]]), array([[21.99995369]]), array([[21.90595462]]), array([[21.84383552]]), array([[21.83495881]]), array([[21.71225964]]), array([[21.60201444]]), array([[21.52997416]]), array([[21.38537467]]), array([[21.34166718]]), array([[21.30683384]]), array([[21.34069716]]), array([[21.28188322]]), array([[21.16824555]]), array([[21.10688064]]), array([[21.03274303]]), array([[20.95408817]]), array([[20.8010064]]), array([[20.74098628]]), array([[20.60616655]]), array([[20.48204322]]), array([[20.34040235]]), array([[20.24559431]]), array([[20.07668242]]), array([[19.95114877]]), array([[19.8641258]]), array([[19.75884328]]), array([[19.71966642]]), array([[19.63327309]]), array([[19.67060763]]), array([[19.66919547]]), array([[19.58181156]]), array([[19.57817533]]), array([[19.52661183]]), array([[19.44807959]]), array([[19.321118]]), array([[19.76069564]]), array([[19.85148172]]), array([[19.92045209]]), array([[20.06204305]]), array([[20.66080219]]), array([[21.24758614]]), array([[21.82263442]]), array([[21.84018173]]), array([[21.9033781]]), array([[22.46531054] ...
